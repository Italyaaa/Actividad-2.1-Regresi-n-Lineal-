# %% [markdown]
# # Actividad_2.1 *Hotel_room*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns 
from funpymodeling.exploratory import freq_tbl

# %%
df = pd.read_excel('Hotel_room.xlsx')
pd.options.display.max_rows = None
df.head(5)
# Out:
#    last_scraped  host_since  host_response_time  host_response_rate  \
# 0             1        3005                   2                1.00
# 1             1        3005                   2                1.00
# 2             1        3005                   2                1.00
# 3             1        3867                   2                0.98
# 4             1        3867                   2                0.98
#
#    host_acceptance_rate  host_is_superhost  host_has_profile_pic  \
# 0                     1                  1                     1
# 1                     1                  1                     1
# 2                     1                  1                     1
# 3                     1                  0                     1
# 4                     1                  0                     1
#
#    host_identity_verified  property_type  room_type  ...  \
# 0                       1             22          4  ...
# ...

# %% [markdown]
# Analizamos los valores nulos

# %%
df.isnull().sum()
# Out:
# last_scraped                                    0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_has_profile_pic                            0
# host_identity_verified                          0
# property_type                                   0
# room_type                                       0
# bathrooms_text                                  0
# price                                           0
# has_availability                                0
# calendar_last_scraped                           0
# first_review                                    0
# last_review                                     0
# instant_bookable                                0
# host_listings_count                             0
# host_total_listings_count                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  12 non-null     int64
#  1   host_since                                    12 non-null     int64
#  2   host_response_time                            12 non-null     int64
#  3   host_response_rate                            12 non-null     float64
#  4   host_acceptance_rate                          12 non-null     int64
#  5   host_is_superhost                             12 non-null     int64
#  6   host_has_profile_pic                          12 non-null     int64
#  7   host_identity_verified                        12 non-null     int64
#  8   property_type                                 12 non-null     int64
# ...

# %%
Corr_Factors= df.corr()
Corr_Factors
# Out:
#                                               last_scraped    host_since  \
# last_scraped                                           NaN           NaN
# host_since                                             NaN  1.000000e+00
# host_response_time                                     NaN           NaN
# host_response_rate                                     NaN -1.000000e+00
# host_acceptance_rate                                   NaN           NaN
# host_is_superhost                                      NaN -1.000000e+00
# host_has_profile_pic                                   NaN           NaN
# host_identity_verified                                 NaN           NaN
# property_type                                          NaN  9.505864e-01
# room_type                                              NaN           NaN
# bathrooms_text                                         NaN  1.000000e+00
# price                                                  NaN  5.462669e-01
# ...

# %%
corr_Factors1= abs(Corr_Factors)
corr_Factors1
# Out:
#                                               last_scraped    host_since  \
# last_scraped                                           NaN           NaN
# host_since                                             NaN  1.000000e+00
# host_response_time                                     NaN           NaN
# host_response_rate                                     NaN  1.000000e+00
# host_acceptance_rate                                   NaN           NaN
# host_is_superhost                                      NaN  1.000000e+00
# host_has_profile_pic                                   NaN           NaN
# host_identity_verified                                 NaN           NaN
# property_type                                          NaN  9.505864e-01
# room_type                                              NaN           NaN
# bathrooms_text                                         NaN  1.000000e+00
# price                                                  NaN  5.462669e-01
# ...

# %%
heat_map= sns.heatmap(corr_Factors1, cmap='coolwarm')
heat_map
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(100, 50))
cax = ax.matshow(corr_Factors1, cmap="Blues")
fig.colorbar(cax)

# Añadir anotaciones manualmente
for i in range(corr_Factors1.shape[0]):
    for j in range(corr_Factors1.shape[1]):
        ax.text(j, i, f"{corr_Factors1.iloc[i, j]:.2f}", 
               ha="center", va="center", fontsize=20)

plt.xticks(range(len(corr_Factors1.columns)), corr_Factors1.columns, rotation=90, fontsize=12)
plt.yticks(range(len(corr_Factors1.index)), corr_Factors1.index, fontsize=12)
plt.show()

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df[['host_total_listings_count', 'calculated_host_listings_count','calculated_host_listings_count_entire_homes']]
Var_Dep= df['host_listings_count']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
import numpy as np
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)

print("El coeficiente de determinaciónes: ", coef_Deter)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print("El coeficiente de correlación es:", coef_Correl)
# Out:
# El coeficiente de determinaciónes:  0.0
# El coeficiente de correlación es: 0.0

# %% [markdown]
# Esto quiere decir que no depende de ella para determinarlas

# %% [markdown]
# ### 10 coeficientes de determinación y correlación mas altos

# %% [markdown]
# 1.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep1= df[['longitude']]
Var_Dep1= df['host_listings_count']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model1= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model1.fit(X=Vars_Indep1, y=Var_Dep1)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model1.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model1.score(Vars_Indep1,Var_Dep1)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter1=model1.score(X=Vars_Indep1, y=Var_Dep1)

print("El coeficiente de determinaciónes: ", coef_Deter1)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl1=np.sqrt(coef_Deter1)
print("El coeficiente de correlación es:", coef_Correl1)
# Out:
# El coeficiente de determinaciónes:  0.0
# El coeficiente de correlación es: 0.0

# %% [markdown]
# 2.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['calculated_host_listings_count']]
Var_Depc= df['calculated_host_listings_count_entire_homes']
modelc= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0

# %% [markdown]
# 3.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['calculated_host_listings_count']]
Var_Depc= df['calculated_host_listings_count_private_rooms']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0

# %% [markdown]
# 4.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['host_listings_count']]
Var_Depc= df['calculated_host_listings_count_entire_homes']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0

# %% [markdown]
# 5.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['host_listings_count']]
Var_Depc= df['calculated_host_listings_count_private_rooms']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0

# %% [markdown]
# 6.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['review_scores_value']]
Var_Depc= df['number_of_reviews_ltm']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  0.013306318505261316
# El coeficiente de correlación es: 0.11535301688842522

# %% [markdown]
# 7.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['number_of_reviews_ltm']]
Var_Depc= df['number_of_reviews']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  0.011172484399541549
# El coeficiente de correlación es: 0.10569997350776181

# %% [markdown]
# 8.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['calculated_host_listings_count_entire_homes']]
Var_Depc= df['calculated_host_listings_count_private_rooms']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0

# %% [markdown]
# 9.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['host_total_listings_count']]
Var_Depc= df['calculated_host_listings_count']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  0.0
# El coeficiente de correlación es: 0.0

# %% [markdown]
# No existe coorelación

# %% [markdown]
# 10.-

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indepc= df[['host_total_listings_count']]
Var_Depc= df['calculated_host_listings_count_entire_homes']
modelc= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
modelc.fit(X=Vars_Indepc, y=Var_Depc)

#Verificamos los coeficientes obtenidos para el modelo ajustado
modelc.__dict__

#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
modelc.score(Vars_Indepc,Var_Depc)

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deterc=modelc.score(X=Vars_Indepc, y=Var_Depc)

print("El coeficiente de determinaciónes: ", coef_Deterc)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correlc=np.sqrt(coef_Deterc)
print("El coeficiente de correlación es:", coef_Correlc)
# Out:
# El coeficiente de determinaciónes:  1.0
# El coeficiente de correlación es: 1.0
